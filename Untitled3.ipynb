# %% [markdown]
# # Importar dados do github

# %%
# Importar missoes lunares
# !git clone https://github.com/giuliasawaki4/analise-missoes-lunares.git
# Out:
# fatal: destination path 'analise-missoes-lunares' already exists and is not an empty directory.

# %% [markdown]
# # Bibliotecas

# %%
# !pip install numpy pandas

# %% [markdown]
# # Código

# %%
import pandas as pd

df_lua = pd.read_csv("/content/analise-missoes-lunares/Moonlanding.csv")

display(df_lua)
# Out:
#                    Mission       Spacecraft Launch Date      Carrier Rocket  \
# 0       Pioneer 0 (Able I)        Pioneer 0   17-Aug-58   Thor DM-18 Able I
# 1            Luna E-1 No.1    Luna E-1 No.1   23-Sep-58                Luna
# 2      Pioneer 1 (Able II)        Pioneer 1   11-Oct-58   Thor DM-18 Able I
# 3            Luna E-1 No.2    Luna E-1 No.2   11-Oct-58                Luna
# 4     Pioneer 2 (Able III)        Pioneer 2   08-Nov-58   Thor DM-18 Able I
# ..                     ...              ...         ...                 ...
# 161  Peregrine Mission One        Peregrine   08-Jan-24  Vulcan Centaur VC2
# 162  Peregrine Mission One      Colmena ? 5   08-Jan-24  Vulcan Centaur VC2
# 163  Peregrine Mission One             Iris   08-Jan-24  Vulcan Centaur VC2
# 164                   IM-1  Nova-C Odysseus   14-Feb-24         Falcon 9 B5
# 165                   IM-1         EagleCam   14-Feb-24         Falcon 9 B5
#
# ...

# %%
# o comando describe mostra dados de estatistica básica sobre a base de dados
df_lua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Mission                 166 non-null    object
#  1   Spacecraft              166 non-null    object
#  2   Launch Date             166 non-null    object
#  3   Carrier Rocket          166 non-null    object
#  4   Operator                166 non-null    object
#  5   Mission Type            166 non-null    object
#  6   Outcome                 166 non-null    object
#  7   Additional Information  165 non-null    object
# dtypes: object(8)
# memory usage: 10.5+ KB

# %%
df_lua.describe
# Out:
# <bound method NDFrame.describe of                    Mission       Spacecraft Launch Date      Carrier Rocket  \
# 0       Pioneer 0 (Able I)        Pioneer 0   17-Aug-58   Thor DM-18 Able I
# 1            Luna E-1 No.1    Luna E-1 No.1   23-Sep-58                Luna
# 2      Pioneer 1 (Able II)        Pioneer 1   11-Oct-58   Thor DM-18 Able I
# 3            Luna E-1 No.2    Luna E-1 No.2   11-Oct-58                Luna
# 4     Pioneer 2 (Able III)        Pioneer 2   08-Nov-58   Thor DM-18 Able I
# ..                     ...              ...         ...                 ...
# 161  Peregrine Mission One        Peregrine   08-Jan-24  Vulcan Centaur VC2
# 162  Peregrine Mission One      Colmena ? 5   08-Jan-24  Vulcan Centaur VC2
# 163  Peregrine Mission One             Iris   08-Jan-24  Vulcan Centaur VC2
# 164                   IM-1  Nova-C Odysseus   14-Feb-24         Falcon 9 B5
# 165                   IM-1         EagleCam   14-Feb-24         Falcon 9 B5
#
# ...

# %%
display(df_lua["Carrier Rocket"].value_counts())
# Out:
# Carrier Rocket
# Proton-K/D                  24
# Molniya-M                   12
# SLS Block 1                 11
# Saturn V                    10
# Luna                         9
# Atlas LV-3 Agena-B           6
# Atlas SLV-3 Agena-D          5
# Molniya-L                    5
# Long March 3C                4
# Atlas LV-3C Centaur-D        4
# Falcon 9 Block 5             4
# Long March 3B                4
# Long March 5                 4
# Thor DM-18 Able I            3
#   H-IIA                      3
# Vulcan Centaur VC2           3
# H-IIA 2022                   3
# Atlas-D Able                 3
# Atlas SLV-3C Centaur-D       3
# Molniya                      3
# Long March 4C                3
# Juno II                      2
# Delta E1                     2
# Falcon 9                     2
# Delta II 7925                2
# PSLV-XL C11                  2
# Atlas V 401                  2
# Falcon 9 B5                  2
# Delta 1913                   1
# ...

# %%
display(df_lua["Carrier Rocket"].value_counts(normalize=True)*100)
# Out:
# Carrier Rocket
# Proton-K/D                  14.457831
# Molniya-M                    7.228916
# SLS Block 1                  6.626506
# Saturn V                     6.024096
# Luna                         5.421687
# Atlas LV-3 Agena-B           3.614458
# Atlas SLV-3 Agena-D          3.012048
# Molniya-L                    3.012048
# Long March 3C                2.409639
# Atlas LV-3C Centaur-D        2.409639
# Falcon 9 Block 5             2.409639
# Long March 3B                2.409639
# Long March 5                 2.409639
# Thor DM-18 Able I            1.807229
#   H-IIA                      1.807229
# Vulcan Centaur VC2           1.807229
# H-IIA 2022                   1.807229
# Atlas-D Able                 1.807229
# Atlas SLV-3C Centaur-D       1.807229
# Molniya                      1.807229
# Long March 4C                1.807229
# Juno II                      1.204819
# Delta E1                     1.204819
# Falcon 9                     1.204819
# ...
